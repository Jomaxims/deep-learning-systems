# %% [markdown]
# <a href="https://colab.research.google.com/github/Jomaxims/deep-learning-systems/blob/main/deep_learning_systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wine type
#
# ### Description
# The two datasets are related to red and white variants of Portuguese wine.
# They contain data about the wines' chemical properties and quality.
# They do not contain any data about the grape variety, vintage, location, winery etc.
#
# There are no missing values.
#
# #### Variables
# 1. fixed acidity
# 1. volatile acidity
# 1. citric acid
# 1. residual sugar
# 1. chlorides
# 1. free sulfur dioxide
# 1. total sulfur dioxide
# 1. density
# 1. pH
# 1. sulphates
# 1. alcohol
# 1. quality
# 1. (color)
#
# ### Hypothesis
# It is possible to predict the type of wine based on its chemical properties.
#
# ### Goal
# The goal is to predict the type of wine between red and white by its chemical properties.
#
# ---
#
# Source: [https://archive.ics.uci.edu/dataset/186/wine+quality](https://archive.ics.uci.edu/dataset/186/wine+quality)

# %%
import pandas as pd

# %%
dfRed = pd.read_csv('https://raw.githubusercontent.com/Jomaxims/deep-learning-systems/refs/heads/main/wine-quality%20Red.csv')
dfRed['red'] = 1
display(dfRed)

dfWhite = pd.read_csv('https://raw.githubusercontent.com/Jomaxims/deep-learning-systems/refs/heads/main/wine-quality%20White.csv')
dfWhite['red'] = 0
display(dfWhite)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Join the red and white wine datasets

df = pd.concat([dfRed, dfWhite])
df.reset_index(drop=True, inplace=True)

display(df)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Remove approx. 1000 duplicates

df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5320 entries, 0 to 5319
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         5320 non-null   float64
#  1   volatile acidity      5320 non-null   float64
#  2   citric acid           5320 non-null   float64
#  3   residual sugar        5320 non-null   float64
#  4   chlorides             5320 non-null   float64
#  5   free sulfur dioxide   5320 non-null   float64
#  6   total sulfur dioxide  5320 non-null   float64
#  7   density               5320 non-null   float64
#  8   pH                    5320 non-null   float64
#  9   sulphates             5320 non-null   float64
#  10  alcohol               5320 non-null   float64
#  11  quality               5320 non-null   int64
#  12  red                   5320 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 540.4 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5320.000000       5320.000000  5320.000000     5320.000000
# mean        7.215179          0.344130     0.318494        5.048477
# std         1.319671          0.168248     0.147157        4.500180
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5320.000000          5320.000000           5320.000000  5320.000000
# mean      0.056690            30.036654            114.109023     0.994535
# std       0.036863            17.805045             56.774223     0.002966
# ...

# %%
df.drop(columns=['red']).hist(bins=50, figsize=(25, 15))
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %%
# Remove outliers using the standard deviation method

from scipy import stats
import numpy as np

df_outliers_filtered = df.select_dtypes(include=['float'])

mask = np.abs(stats.zscore(df_outliers_filtered)) < 3
df = df[mask.all(axis=1)]
df.reset_index(drop=True, inplace=True)

# %%
df.drop(columns=['red']).hist(bins=50, figsize=(25, 15))
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.200945     0.244296
# volatile acidity           0.200945          1.000000    -0.448108
# citric acid                0.244296         -0.448108     1.000000
# residual sugar            -0.089246         -0.165248     0.164949
# chlorides                  0.361348          0.494341    -0.127661
# free sulfur dioxide       -0.256815         -0.347700     0.187264
# total sulfur dioxide      -0.280354         -0.397029     0.261576
# density                    0.428920          0.295947     0.024463
# pH                        -0.234347          0.248936    -0.308163
# sulphates                  0.234389          0.229185    -0.020808
# alcohol                   -0.109282         -0.072048     0.011565
# quality                   -0.091061         -0.233470     0.097186
# red                        0.444359          0.651958    -0.267980
#
# ...

# %%
import seaborn as sns

sns.pairplot(df, hue='red', height=2.5, kind='hist', diag_kind='kde', palette={ 0:"yellow", 1:"red"});

# %%
df.drop(columns=['alcohol', 'quality'], inplace=True)

display(df)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.76         0.04             2.3      0.092
# 2               7.4              0.66         0.00             1.8      0.075
# 3               7.9              0.60         0.06             1.6      0.069
# 4               7.3              0.65         0.00             1.2      0.065
# ...             ...               ...          ...             ...        ...
# 4884            6.2              0.21         0.29             1.6      0.039
# 4885            6.6              0.32         0.36             8.0      0.047
# 4886            6.5              0.24         0.19             1.2      0.041
# 4887            5.5              0.29         0.30             1.1      0.022
# 4888            6.0              0.21         0.38             0.8      0.020
#
# ...
